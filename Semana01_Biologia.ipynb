# %% [markdown]
# <a href="https://colab.research.google.com/github/clobos/Biologia_2026/blob/main/Semana01_Biologia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pergunta 1: O que é Estatística?

# %% [markdown]
# # Pergunta 2: Para que serve a Estatística?

# %% [markdown]
# # Tipos de variáveis

# %% [markdown]
# ## Qual. nominal
# - Exemplo 1
# - Exemplo 2
# - Exemplo 3

# %% [markdown]
# ## Qual. ordinal
# - Exemplo 1
# - Exemplo 2
# - Exemplo 3

# %% [markdown]
# ## Quant. discreta
# - Exemplo 1
# - Exemplo 2
# - Exemplo 3

# %% [markdown]
# ## Quant. continua
# - Exemplo 1
# - Exemplo 2
# - Exemplo 3

# %%
import pandas as pd
df = pd.read_excel('dados_semana1.xlsx')
df
# Out:
#    Quantos cafés você consumiu nas últimas 24 horas?  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                          6 xicaras
# 5                                                  1
# 6                                                  2
# 7                                                  0
# 8                                          4 canecas
# 9                                                  1
# 10                                        3 xícaras
# 11                                                 0
# 12                                                 2
# 13                                           Nenhum
# 14                                                 7
# 15                                                 3
# 16                                                 1
# ...

# %%
linhas, colunas = df.shape
print(f"Número de linhas: {linhas}")
print(f"Número de colunas: {colunas}\n")
# Out:
# Número de linhas: 24
# Número de colunas: 9

# %%
print("Tipos de variáveis (dtypes):")
print(df.dtypes)
# Out:
# Tipos de variáveis (dtypes):
# Quantos cafés você consumiu nas últimas 24 horas?                                 object
# Qual é a temperatura ideal, em °C, para beber café filtrado?                      object
# Qual dessas frutas você prefere para suco natural?                                object
# Como você classificaria o nível de doçura ideal de um iogurte?                    object
# Quantas refeições você faz por dia, em média?                                     object
# Qual foi o peso, em gramas, da última porção de arroz que você consumiu?          object
# Qual tipo de dieta você segue atualmente?                                         object
# Como você avalia sua preferência por alimentos crocantes?                          int64
# Quanto tempo, em minutos, você normalmente leva para preparar o café da manhã?    object
# dtype: object

# %%
# Informações detalhadas do DataFrame
print("Informações gerais do banco:")
df.info()
# Out:
# Informações gerais do banco:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 9 columns):
#  #   Column                                                                          Non-Null Count  Dtype
# ---  ------                                                                          --------------  -----
#  0   Quantos cafés você consumiu nas últimas 24 horas?                               24 non-null     object
#  1   Qual é a temperatura ideal, em °C, para beber café filtrado?                    24 non-null     object
#  2   Qual dessas frutas você prefere para suco natural?                              24 non-null     object
#  3   Como você classificaria o nível de doçura ideal de um iogurte?                  24 non-null     object
#  4   Quantas refeições você faz por dia, em média?                                   24 non-null     object
# ...

# %%
print("5 primeiras linhas:")
display(df.head())
# Out:
# 5 primeiras linhas:
#   Quantos cafés você consumiu nas últimas 24 horas?  \
# 0                                                 0
# 1                                                 0
# 2                                                 0
# 3                                                 0
# 4                                         6 xicaras
#
#   Qual é a temperatura ideal, em °C, para beber café filtrado?  \
# 0                                                  0
# 1                                                 70
# 2                                                 40
# 3                                                 50
# 4                                              30°C?
#
#   Qual dessas frutas você prefere para suco natural?  \
# 0                                              Manga
# 1                                           Maracujá
# 2                                            Laranja
# 3                                            Laranja
# ...

# %%
print("5 últimas linhas:")
display(df.tail())
# Out:
# 5 últimas linhas:
#    Quantos cafés você consumiu nas últimas 24 horas?  \
# 19                                                 0
# 20                                                 2
# 21                                                 0
# 22                                            nenhum
# 23                                                 1
#
#    Qual é a temperatura ideal, em °C, para beber café filtrado?  \
# 19                                                50º
# 20                                                 50
# 21                                                 35
# 22                                                 65
# 23                                                 65
#
#    Qual dessas frutas você prefere para suco natural?  \
# 19                                            Laranja
# 20                                            Laranja
# 21                                            Laranja
# 22                                           Maracujá
# ...

# %%
print("Quantidade de valores ausentes por coluna:")
print(df.isna().sum())
# Out:
# Quantidade de valores ausentes por coluna:
# Quantos cafés você consumiu nas últimas 24 horas?                                 0
# Qual é a temperatura ideal, em °C, para beber café filtrado?                      0
# Qual dessas frutas você prefere para suco natural?                                0
# Como você classificaria o nível de doçura ideal de um iogurte?                    0
# Quantas refeições você faz por dia, em média?                                     0
# Qual foi o peso, em gramas, da última porção de arroz que você consumiu?          0
# Qual tipo de dieta você segue atualmente?                                         0
# Como você avalia sua preferência por alimentos crocantes?                         0
# Quanto tempo, em minutos, você normalmente leva para preparar o café da manhã?    0
# dtype: int64

# %%
print("Percentual de valores ausentes por coluna:")
print((df.isna().mean() * 100).round(2))
# Out:
# Percentual de valores ausentes por coluna:
# Quantos cafés você consumiu nas últimas 24 horas?                                 0.0
# Qual é a temperatura ideal, em °C, para beber café filtrado?                      0.0
# Qual dessas frutas você prefere para suco natural?                                0.0
# Como você classificaria o nível de doçura ideal de um iogurte?                    0.0
# Quantas refeições você faz por dia, em média?                                     0.0
# Qual foi o peso, em gramas, da última porção de arroz que você consumiu?          0.0
# Qual tipo de dieta você segue atualmente?                                         0.0
# Como você avalia sua preferência por alimentos crocantes?                         0.0
# Quanto tempo, em minutos, você normalmente leva para preparar o café da manhã?    0.0
# dtype: float64

# %%
print("Resumo estatístico das variáveis numéricas:")
display(df.describe())
# Out:
# Resumo estatístico das variáveis numéricas:
#        Como você avalia sua preferência por alimentos crocantes?
# count                                          24.000000
# mean                                            3.958333
# std                                             1.334465
# min                                             1.000000
# 25%                                             3.750000
# 50%                                             4.000000
# 75%                                             5.000000
# max                                             5.000000
